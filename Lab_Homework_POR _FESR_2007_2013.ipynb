# %%
<img src="img/CoverDAF.png">

# %% [markdown]
# # Lab Homework
#
# ## Progetti finanziati con fondi POR FESR 2007-2013
#
# Sul sito open data della regione Umbria sono stati pubblicati il 30 luglio 2018 i dati relativi ai progetti finanziati con fondi POR FESR 2007-2013
#
# I dataset sono quattro:
#
# - soggetti
#
# - pagamenti
#
# - progetti
#
# - localizzazioni
#
# Essi rappresentano un ottima occasione su cui esercitarsi utilizzando gli spunti offerti durante la lezioni, si per impratichirsi con Python/pandas che in DAF creando widget e dashboard di consultazione.
#
#
#
#
#
# Rif:
# http://dati.umbria.it/dataset/progetti-fondi-por-fesr-2007-2013

# %%
import pandas as pd

# %%
soggetti = pd.read_csv("http://dati.umbria.it/datastore/dump/c451532e-ecc6-4601-8615-2d562b41fa4c")

# %%
pagamenti = pd.read_csv("http://dati.umbria.it/datastore/dump/2b683c58-09ca-4159-ad6b-a0f09d2d17ef")

# %%
progetti = pd.read_csv("http://dati.umbria.it/datastore/dump/9a43f45c-79df-4ab7-8b5b-c8c6395292a1")

# %%
localizzazioni = pd.read_csv("http://dati.umbria.it/datastore/dump/31c9e8f0-d368-4d21-8026-f03b58f10dfa")

# %%
progetti.head(4).T
# Out:
#                                                                                  0  \
# _id                                                                              1
# COD_LOCALE_PROGETTO                                                       3UM10045
# CUP                                                                I78F09000030007
# OC_TITOLO_PROGETTO                      PIA2008 INNOVAZIONE  _ICATSRL INVESTIMENTI
# QSN_AREA_OBIETTIVO_UE                    www.opencoesione.gov.it/progetti/3um10045
# QSN_FONDO_COMUNITARIO                       CompetitivitÃ  regionale e occupazione
# QSN_COD_PRIORITA                                                              FESR
# QSN_DESCRIZIONE_PRIORITA                                                         2
# QSN_COD_OBIETTIVO_GENERALE       Promozione, valorizzazione e diffusione della ...
# QSN_DESCR_OBIETTIVO_GENERALE                                                   2.1
# ...

# %%
soggetti.head(4).T
# Out:
#                                                                             0  \
# _id                                                                         1
# COD_LOCALE_PROGETTO                                                  3UM10045
# SOGG_COD_RUOLO                                                              1
# SOGG_DESCR_RUOLO                                   Programmatore del progetto
# SOGG_PROGR_RUOLO                                                            1
# OC_CODICE_FISCALE_SOGG
# OC_DENOMINAZIONE_SOGG                                          REGIONE UMBRIA
# COD_FORMA_GIURIDICA_SOGG                                               2.4.10
# DESCR_FORMA_GIURIDICA_SOGG                                            Regione
# COD_COMUNE_SEDE_SOGG
# INDIRIZZO_SOGG
# CAP_SOGG
# COD_ATECO_SOGG                                                     O-84.11.10
# DESCRIZIONE_ATECO_SOGG      AttivitÃÂ  degli organi legislativi ed esecut...
# COD_ADDETTI_SOGG
# DESCR_ADDETTI_SOGG
# ...

# %%
pagamenti.head(4).T
# Out:
#                                         0          1         2         3
# _id                                     1          2         3         4
# COD_LOCALE_PROGETTO              3UM10045   3UM10045  3UM10081  3UM10081
# DATA_AGGIORNAMENTO               20120729   20120730  20120808  20120809
# TOT_PAGAMENTI                        0,00  191701,93      0,00  12024,25
# OC_TOT_PAGAMENTI_RENDICONTAB_UE      0,00  191701,93      0,00  12024,25
# OC_TOT_PAGAMENTI_FSC                 0,00       0,00      0,00      0,00
# OC_TOT_PAGAMENTI_PAC                 0,00       0,00      0,00      0,00

# %%
localizzazioni.head(4).T
# Out:
#                                            0                              1  \
# _id                                        1                              2
# COD_LOCALE_PROGETTO                 3UM10045                       3UM10081
# COD_REGIONE                               10                             10
# DEN_REGIONE                           UMBRIA                         UMBRIA
# COD_PROVINCIA                             54                             54
# DEN_PROVINCIA                        PERUGIA                        PERUGIA
# COD_COMUNE                                19                             39
# DEN_COMUNE                   Fossato Di Vico                        Perugia
# INDIRIZZO_PROG                          1006                           1009
# CAP_PROG                       GUALDO TADINO                        PERUGIA
# OC_TERRITORIO_PROG   Via dell'Arbetraccio, 6  Via Giovanni Amendola, n. 123
# ...
